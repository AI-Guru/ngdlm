# %%
from keras import models, layers
from ngdlm import models as ngdlmodels
from ngdlm import utils as ngdlutils
from keras.datasets import mnist
import numpy as np
# Out:
# Using TensorFlow backend.
# /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Train- and test-data.

# %%
(x_input_train, _), (x_input_test, y_output_test) = mnist.load_data()
x_input_train = x_input_train.astype("float32") / 255.0
x_input_test = x_input_test.astype("float32") / 255.0
print(x_input_train.shape)
print(x_input_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# # Generator.

# %%
def train_generator():
    while True:
        yield x_input_train, x_input_train
        
def validate_generator():
    while True:
        yield x_input_test, x_input_test

# %% [markdown]
# # Plain autoencoder.

# %%
latent_dim = 32

# Create the encoder.
encoder_input = layers.Input(shape=(28, 28))
encoder_output = encoder_input
encoder_output = layers.Reshape((28 * 28,))(encoder_input)
encoder_output = layers.Dense(latent_dim, activation="relu")(encoder_output)
encoder = models.Model(encoder_input, encoder_output)

# Create the decoder.
decoder_input = layers.Input(shape=(latent_dim,))
decoder_output = layers.Dense(28 * 28, activation="sigmoid")(decoder_input)
decoder_output = layers.Reshape((28, 28))(decoder_output)
decoder = models.Model(decoder_input, decoder_output)

# Create the autoencoder.
ae = ngdlmodels.AE(encoder, decoder)
ae.compile(optimizer='adadelta', loss='binary_crossentropy')
ae.summary()

# Train.
print("Train...")
history = ae.fit_generator(
        train_generator(),
        steps_per_epoch=1,
        epochs=50,
        validation_data=validate_generator(),
        validation_steps=1
    )
    
# Evaluate.
print("Evaluate...")
loss = ae.evaluate(x_input_test, x_input_test)
print("Loss:", loss)
# Out:
# Encoder:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# Autoencoder:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# model_1 (Model)              (None, 32)                25120
# _________________________________________________________________
# model_2 (Model)              (None, 28, 28)            25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Epoch 1/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.6957 - val_loss: 0.6950
# Epoch 2/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6950 - val_loss: 0.6943
# Epoch 3/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6936
# Epoch 4/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6937 - val_loss: 0.6931
# Epoch 5/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6931 - val_loss: 0.6925
# Epoch 6/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6925 - val_loss: 0.6919
# Epoch 7/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6920 - val_loss: 0.6914
# Epoch 8/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6915 - val_loss: 0.6909
# Epoch 9/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6909 - val_loss: 0.6903
# Epoch 10/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6904 - val_loss: 0.6898
# Epoch 11/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6898 - val_loss: 0.6892
# Epoch 12/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6893 - val_loss: 0.6886
# Epoch 13/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6887 - val_loss: 0.6880
# Epoch 14/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6881 - val_loss: 0.6873
# Epoch 15/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6874 - val_loss: 0.6866
# Epoch 16/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6867 - val_loss: 0.6858
# Epoch 17/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6859 - val_loss: 0.6849
# Epoch 18/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6851 - val_loss: 0.6840
# Epoch 19/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6841 - val_loss: 0.6829
# Epoch 20/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6831 - val_loss: 0.6818
# Epoch 21/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6820 - val_loss: 0.6805
# Epoch 22/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6807 - val_loss: 0.6791
# Epoch 23/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6793 - val_loss: 0.6775
# Epoch 24/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6778 - val_loss: 0.6757
# Epoch 25/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6760 - val_loss: 0.6738
# Epoch 26/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6741 - val_loss: 0.6716
# Epoch 27/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6719 - val_loss: 0.6691
# Epoch 28/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6695 - val_loss: 0.6664
# Epoch 29/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6669 - val_loss: 0.6634
# Epoch 30/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6639 - val_loss: 0.6600
# Epoch 31/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6605 - val_loss: 0.6562
# Epoch 32/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6569 - val_loss: 0.6521
# Epoch 33/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6528 - val_loss: 0.6475
# Epoch 34/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6483 - val_loss: 0.6425
# Epoch 35/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6433 - val_loss: 0.6369
# Epoch 36/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6378 - val_loss: 0.6309
# Epoch 37/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6319 - val_loss: 0.6243
# Epoch 38/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6254 - val_loss: 0.6171
# Epoch 39/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6183 - val_loss: 0.6094
# Epoch 40/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6107 - val_loss: 0.6010
# Epoch 41/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6025 - val_loss: 0.5921
# Epoch 42/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5937 - val_loss: 0.5827
# Epoch 43/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5843 - val_loss: 0.5727
# Epoch 44/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5745 - val_loss: 0.5622
# Epoch 45/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5642 - val_loss: 0.5513
# Epoch 46/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5534 - val_loss: 0.5401
# Epoch 47/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5422 - val_loss: 0.5285
# Epoch 48/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5307 - val_loss: 0.5166
# Epoch 49/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5190 - val_loss: 0.5047
# Epoch 50/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.5072 - val_loss: 0.4927
# Evaluate...
# 10000/10000 [==============================] - 0s 27us/step
# Loss: 0.4926741961479187

# %% [markdown]
# # Visualizing plain autoencoder.

# %%
print("Rendering history...")
ngdlutils.render_history(history)

print("Rendering reconstructions...")
ngdlutils.render_image_reconstructions(ae, x_input_train[0:10])

print("Rendering latent-space...")
ngdlutils.render_image_latent_space(ae.decoder, 10)

print("Rendering encodings...")
ngdlutils.render_encodings(ae.encoder, x_input_test, y_output_test)
# Out:
# Rendering history...
# Rendering reconstructions...
# Rendering latent-space...
# Rendering encodings...
