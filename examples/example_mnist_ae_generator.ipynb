# %%
from tensorflow.keras import models, layers
from ngdlm import models as ngdlmodels
from ngdlm import utils as ngdlutils
from tensorflow.keras.datasets import mnist
import numpy as np

# %% [markdown]
# # Train- and test-data.

# %%
(x_input_train, _), (x_input_test, y_output_test) = mnist.load_data()
x_input_train = x_input_train.astype("float32") / 255.0
x_input_test = x_input_test.astype("float32") / 255.0
print(x_input_train.shape)
print(x_input_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# # Generator.

# %%
def train_generator():
    while True:
        yield x_input_train, x_input_train
        
def validate_generator():
    while True:
        yield x_input_test, x_input_test

# %% [markdown]
# # Plain autoencoder.

# %%
latent_dim = 32

# Create the encoder.
encoder_input = layers.Input(shape=(28, 28))
encoder_output = encoder_input
encoder_output = layers.Reshape((28 * 28,))(encoder_input)
encoder_output = layers.Dense(latent_dim, activation="relu")(encoder_output)
encoder = models.Model(encoder_input, encoder_output)

# Create the decoder.
decoder_input = layers.Input(shape=(latent_dim,))
decoder_output = layers.Dense(28 * 28, activation="sigmoid")(decoder_input)
decoder_output = layers.Reshape((28, 28))(decoder_output)
decoder = models.Model(decoder_input, decoder_output)

# Create the autoencoder.
ae = ngdlmodels.AE(encoder, decoder)
ae.compile(optimizer='adadelta', loss='binary_crossentropy')
ae.summary()

# Train.
print("Train...")
history = ae.fit_generator(
        train_generator(),
        steps_per_epoch=1,
        epochs=50,
        validation_data=validate_generator(),
        validation_steps=1
    )
    
# Evaluate.
print("Evaluate...")
loss = ae.evaluate(x_input_test, x_input_test)
print("Loss:", loss)
# Out:
# WARNING:tensorflow:From /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Encoder:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# Decoder:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               25872
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# Autoencoder:
# Model: "ae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# model (Model)                (None, 32)                25120
# _________________________________________________________________
# model_1 (Model)              (None, 28, 28)            25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Epoch 1/50
# WARNING:tensorflow:From /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 1/1 [==============================] - 4s 4s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 2/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 3/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 4/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 5/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 6/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 7/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 8/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 9/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 10/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 11/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 12/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 13/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 14/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 15/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 16/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 17/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 18/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 19/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 20/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 21/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 22/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 23/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 24/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 25/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 26/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 27/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 28/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 29/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 30/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 31/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 32/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 33/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 34/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6943 - val_loss: 0.6944
# Epoch 35/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 36/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 37/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 38/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 39/50
# 1/1 [==============================] - 7s 7s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 40/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 41/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 42/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 43/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 44/50
# 1/1 [==============================] - 7s 7s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 45/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 46/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 47/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 48/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 49/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Epoch 50/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.6943 - val_loss: 0.6943
# Evaluate...
# 10000/10000 [==============================] - 2s 181us/sample - loss: 0.6943s - lo - ETA: 0s - loss: 0.6 - ETA: 0s - loss: 0.
# Loss: 0.6943410969734192

# %% [markdown]
# # Visualizing plain autoencoder.

# %%
print("Rendering history...")
ngdlutils.render_history(history)

print("Rendering reconstructions...")
ngdlutils.render_image_reconstructions(ae, x_input_train[0:10])

print("Rendering latent-space...")
ngdlutils.render_image_latent_space(ae.decoder, 10)

print("Rendering encodings...")
ngdlutils.render_encodings(ae.encoder, x_input_test, y_output_test)
# Out:
# Rendering history...
# Rendering reconstructions...
# Rendering latent-space...
# Rendering encodings...
