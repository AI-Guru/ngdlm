# %% [markdown]
# # Variational Autoencoder on Fashion-MNIST.
#
# Trains a VAE on Fashion-MNIST.

# %%
from keras import models, layers
from ngdlm import models as ngdlmodels
from ngdlm import utils as ngdlutils
from keras.datasets import fashion_mnist
import numpy as np
# Out:
# Using TensorFlow backend.
# /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/tristanbehrens/Development/python-venvs/venv-3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Train- and test-data.

# %%
(x_input_train, _), (x_input_test, y_output_test) = fashion_mnist.load_data()
x_input_train = x_input_train.astype("float32") / 255.0
x_input_test = x_input_test.astype("float32") / 255.0
print(x_input_train.shape)
print(x_input_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# # Variational autoencoder.

# %%
latent_dim = 2

# Create the encoder.
encoder_input = layers.Input(shape=(28, 28))
encoder_output = layers.Reshape((28 * 28,))(encoder_input)
encoder_output = layers.Dense(512, activation="relu")(encoder_output)
encoder = models.Model(encoder_input, encoder_output)

# Create the decoder.
decoder_input = layers.Input(shape=(latent_dim,))
decoder_output = layers.Dense(512, activation="relu")(decoder_input)
decoder_output = layers.Dense(28 * 28, activation="sigmoid")(decoder_output)
decoder_output = layers.Reshape((28, 28))(decoder_output)
decoder = models.Model(decoder_input, decoder_output)

# Create the autoencoder.
vae = ngdlmodels.VAE(encoder, decoder, latent_dim=latent_dim)
vae.compile(optimizer='adadelta', loss="binary_crossentropy")
vae.summary()

# Train.
print("Train...")
history = vae.fit(
        x_input_train, x_input_train,
        epochs=100,
        batch_size=32,
        shuffle=True,
        validation_data=(x_input_test, x_input_test)
    )
    
# Evaluate.
print("Evaluate...")
loss = vae.evaluate(x_input_test, x_input_test)
print("Loss:", loss)
# Out:
# Encoder:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 784)          0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          401920      reshape_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            1026        dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            1026        dense_1[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 403,972
# Trainable params: 403,972
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Decoder:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               402192
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 403,728
# Trainable params: 403,728
# Non-trainable params: 0
# _________________________________________________________________
# Autoencoder:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# encoder (Model)              [(None, 2), (None, 2), (N 403972
# _________________________________________________________________
# model_2 (Model)              (None, 28, 28)            403728
# =================================================================
# Total params: 807,700
# Trainable params: 807,700
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 16s 269us/step - loss: 0.4236 - val_loss: 0.3812
# Epoch 2/100
# 60000/60000 [==============================] - 16s 269us/step - loss: 0.3733 - val_loss: 0.3702
# Epoch 3/100
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3646 - val_loss: 0.3628
# Epoch 4/100
# 60000/60000 [==============================] - 15s 252us/step - loss: 0.3600 - val_loss: 0.3595
# Epoch 5/100
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3573 - val_loss: 0.3574
# Epoch 6/100
# 60000/60000 [==============================] - 17s 290us/step - loss: 0.3554 - val_loss: 0.3560
# Epoch 7/100
# 60000/60000 [==============================] - 15s 258us/step - loss: 0.3539 - val_loss: 0.3544
# Epoch 8/100
# 60000/60000 [==============================] - 12s 205us/step - loss: 0.3526 - val_loss: 0.3537
# Epoch 9/100
# 60000/60000 [==============================] - 12s 193us/step - loss: 0.3514 - val_loss: 0.3520
# Epoch 10/100
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.3503 - val_loss: 0.3519
# Epoch 11/100
# 60000/60000 [==============================] - 12s 202us/step - loss: 0.3494 - val_loss: 0.3505
# Epoch 12/100
# 60000/60000 [==============================] - 13s 215us/step - loss: 0.3486 - val_loss: 0.3495
# Epoch 13/100
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3479 - val_loss: 0.3491
# Epoch 14/100
# 60000/60000 [==============================] - 16s 264us/step - loss: 0.3473 - val_loss: 0.3481
# Epoch 15/100
# 60000/60000 [==============================] - 16s 266us/step - loss: 0.3467 - val_loss: 0.3480
# Epoch 16/100
# 60000/60000 [==============================] - 17s 276us/step - loss: 0.3462 - val_loss: 0.3474
# Epoch 17/100
# 60000/60000 [==============================] - 15s 244us/step - loss: 0.3457 - val_loss: 0.3469
# Epoch 18/100
# 60000/60000 [==============================] - 14s 237us/step - loss: 0.3452 - val_loss: 0.3479
# Epoch 19/100
# 60000/60000 [==============================] - 15s 257us/step - loss: 0.3448 - val_loss: 0.3462
# Epoch 20/100
# 60000/60000 [==============================] - 17s 277us/step - loss: 0.3444 - val_loss: 0.3458
# Epoch 21/100
# 60000/60000 [==============================] - 15s 251us/step - loss: 0.3441 - val_loss: 0.3454
# Epoch 22/100
# 60000/60000 [==============================] - 15s 248us/step - loss: 0.3438 - val_loss: 0.3454
# Epoch 23/100
# 60000/60000 [==============================] - 15s 249us/step - loss: 0.3434 - val_loss: 0.3448
# Epoch 24/100
# 60000/60000 [==============================] - 12s 208us/step - loss: 0.3431 - val_loss: 0.3449
# Epoch 25/100
# 60000/60000 [==============================] - 12s 196us/step - loss: 0.3429 - val_loss: 0.3442
# Epoch 26/100
# 60000/60000 [==============================] - 15s 257us/step - loss: 0.3426 - val_loss: 0.3439
# Epoch 27/100
# 60000/60000 [==============================] - 22s 365us/step - loss: 0.3423 - val_loss: 0.3436
# Epoch 28/100
# 60000/60000 [==============================] - 21s 343us/step - loss: 0.3421 - val_loss: 0.3437
# Epoch 29/100
# 60000/60000 [==============================] - 20s 336us/step - loss: 0.3418 - val_loss: 0.3443
# Epoch 30/100
# 60000/60000 [==============================] - 21s 343us/step - loss: 0.3416 - val_loss: 0.3431
# Epoch 31/100
# 60000/60000 [==============================] - 22s 361us/step - loss: 0.3414 - val_loss: 0.3428
# Epoch 32/100
# 60000/60000 [==============================] - 21s 358us/step - loss: 0.3412 - val_loss: 0.3427
# Epoch 33/100
# 60000/60000 [==============================] - 21s 351us/step - loss: 0.3410 - val_loss: 0.3425
# Epoch 34/100
# 60000/60000 [==============================] - 14s 228us/step - loss: 0.3408 - val_loss: 0.3436
# Epoch 35/100
# 60000/60000 [==============================] - 17s 278us/step - loss: 0.3406 - val_loss: 0.3419
# Epoch 36/100
# 60000/60000 [==============================] - 17s 287us/step - loss: 0.3404 - val_loss: 0.3432
# Epoch 37/100
# 60000/60000 [==============================] - 22s 369us/step - loss: 0.3402 - val_loss: 0.3422
# Epoch 38/100
# 60000/60000 [==============================] - 23s 380us/step - loss: 0.3400 - val_loss: 0.3417
# Epoch 39/100
# 60000/60000 [==============================] - 23s 378us/step - loss: 0.3398 - val_loss: 0.3418
# Epoch 40/100
# 60000/60000 [==============================] - 22s 359us/step - loss: 0.3397 - val_loss: 0.3416
# Epoch 41/100
# 60000/60000 [==============================] - 23s 382us/step - loss: 0.3395 - val_loss: 0.3416
# Epoch 42/100
# 60000/60000 [==============================] - 22s 369us/step - loss: 0.3393 - val_loss: 0.3412
# Epoch 43/100
# 60000/60000 [==============================] - 23s 382us/step - loss: 0.3391 - val_loss: 0.3411
# Epoch 44/100
# 60000/60000 [==============================] - 23s 385us/step - loss: 0.3390 - val_loss: 0.3411
# Epoch 45/100
# 60000/60000 [==============================] - 23s 381us/step - loss: 0.3388 - val_loss: 0.3407
# Epoch 46/100
# 60000/60000 [==============================] - 23s 383us/step - loss: 0.3387 - val_loss: 0.3403
# Epoch 47/100
# 60000/60000 [==============================] - 23s 379us/step - loss: 0.3385 - val_loss: 0.3408
# Epoch 48/100
# 60000/60000 [==============================] - 21s 357us/step - loss: 0.3384 - val_loss: 0.3402
# Epoch 49/100
# 60000/60000 [==============================] - 21s 357us/step - loss: 0.3383 - val_loss: 0.3400
# Epoch 50/100
# 60000/60000 [==============================] - 22s 362us/step - loss: 0.3382 - val_loss: 0.3400
# Epoch 51/100
# 60000/60000 [==============================] - 23s 376us/step - loss: 0.3380 - val_loss: 0.3400
# Epoch 52/100
# 60000/60000 [==============================] - 23s 389us/step - loss: 0.3379 - val_loss: 0.3400
# Epoch 53/100
# 60000/60000 [==============================] - 27s 448us/step - loss: 0.3378 - val_loss: 0.3400
# Epoch 54/100
# 60000/60000 [==============================] - 38s 625us/step - loss: 0.3377 - val_loss: 0.3395
# Epoch 55/100
# 60000/60000 [==============================] - 43s 709us/step - loss: 0.3376 - val_loss: 0.3419
# Epoch 56/100
# 60000/60000 [==============================] - 41s 681us/step - loss: 0.3375 - val_loss: 0.3402
# Epoch 57/100
# 60000/60000 [==============================] - 44s 736us/step - loss: 0.3375 - val_loss: 0.3396
# Epoch 58/100
# 60000/60000 [==============================] - 41s 685us/step - loss: 0.3374 - val_loss: 0.3392
# Epoch 59/100
# 60000/60000 [==============================] - 43s 713us/step - loss: 0.3373 - val_loss: 0.3391
# Epoch 60/100
# 60000/60000 [==============================] - 43s 711us/step - loss: 0.3373 - val_loss: 0.3394
# Epoch 61/100
# 60000/60000 [==============================] - 42s 705us/step - loss: 0.3372 - val_loss: 0.3407
# Epoch 62/100
# 60000/60000 [==============================] - 42s 696us/step - loss: 0.3372 - val_loss: 0.3399
# Epoch 63/100
# 60000/60000 [==============================] - 42s 708us/step - loss: 0.3371 - val_loss: 0.3394
# Epoch 65/100
# 60000/60000 [==============================] - 42s 708us/step - loss: 0.3371 - val_loss: 0.3404
# Epoch 68/100
# 60000/60000 [==============================] - 30s 500us/step - loss: 0.3369 - val_loss: 0.3407
# Epoch 69/100
# 60000/60000 [==============================] - 20s 337us/step - loss: 0.3366 - val_loss: 0.3383
# Epoch 70/100
# 60000/60000 [==============================] - 18s 299us/step - loss: 0.3364 - val_loss: 0.3387
# Epoch 71/100
# 60000/60000 [==============================] - 17s 282us/step - loss: 0.3363 - val_loss: 0.3387
# Epoch 72/100
# 60000/60000 [==============================] - 17s 282us/step - loss: 0.3362 - val_loss: 0.3391
# Epoch 73/100
# 60000/60000 [==============================] - 18s 294us/step - loss: 0.3361 - val_loss: 0.3381
# Epoch 74/100
# 60000/60000 [==============================] - 19s 309us/step - loss: 0.3360 - val_loss: 0.3383
# Epoch 75/100
# 60000/60000 [==============================] - 17s 277us/step - loss: 0.3359 - val_loss: 0.3385
# Epoch 76/100
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.3358 - val_loss: 0.3386
# Epoch 77/100
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3357 - val_loss: 0.3382
# Epoch 78/100
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3357 - val_loss: 0.3379
# Epoch 79/100
# 60000/60000 [==============================] - 17s 288us/step - loss: 0.3356 - val_loss: 0.3392
# Epoch 80/100
# 60000/60000 [==============================] - 17s 282us/step - loss: 0.3355 - val_loss: 0.3378
# Epoch 81/100
# 60000/60000 [==============================] - 18s 303us/step - loss: 0.3355 - val_loss: 0.3377
# Epoch 82/100
# 60000/60000 [==============================] - 16s 265us/step - loss: 0.3354 - val_loss: 0.3388
# Epoch 83/100
# 60000/60000 [==============================] - 16s 269us/step - loss: 0.3353 - val_loss: 0.3375
# Epoch 84/100
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.3352 - val_loss: 0.3405
# Epoch 85/100
# 60000/60000 [==============================] - 17s 276us/step - loss: 0.3352 - val_loss: 0.3377
# Epoch 86/100
# 60000/60000 [==============================] - 17s 275us/step - loss: 0.3351 - val_loss: 0.3382
# Epoch 87/100
# 60000/60000 [==============================] - 16s 270us/step - loss: 0.3351 - val_loss: 0.3383
# Epoch 88/100
# 60000/60000 [==============================] - 16s 270us/step - loss: 0.3350 - val_loss: 0.3379
# Epoch 89/100
# 60000/60000 [==============================] - 16s 271us/step - loss: 0.3350 - val_loss: 0.3382
# Epoch 90/100
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.3349 - val_loss: 0.3379
# Epoch 91/100
# 60000/60000 [==============================] - 16s 273us/step - loss: 0.3349 - val_loss: 0.3377
# Epoch 92/100
# 60000/60000 [==============================] - 18s 295us/step - loss: 0.3348 - val_loss: 0.3376
# Epoch 93/100
# 60000/60000 [==============================] - 19s 310us/step - loss: 0.3348 - val_loss: 0.3394
# Epoch 94/100
# 60000/60000 [==============================] - 16s 272us/step - loss: 0.3347 - val_loss: 0.3383
# Epoch 95/100
# 60000/60000 [==============================] - 16s 268us/step - loss: 0.3346 - val_loss: 0.3374
# Epoch 96/100
# 60000/60000 [==============================] - 16s 271us/step - loss: 0.3346 - val_loss: 0.3378
# Epoch 97/100
# 60000/60000 [==============================] - 16s 266us/step - loss: 0.3345 - val_loss: 0.3378
# Epoch 98/100
# 60000/60000 [==============================] - 16s 267us/step - loss: 0.3345 - val_loss: 0.3371
# Epoch 99/100
# 60000/60000 [==============================] - 17s 275us/step - loss: 0.3344 - val_loss: 0.3382
# Epoch 100/100
# 60000/60000 [==============================] - 17s 277us/step - loss: 0.3344 - val_loss: 0.3370
# Evaluate...
# 10000/10000 [==============================] - 0s 38us/step
# Loss: 0.3371309600353241

# %% [markdown]
# # Visualizing variational autoencoder.

# %%
print("Rendering history...")
ngdlutils.render_history(history)

print("Rendering reconstructions...")
ngdlutils.render_image_reconstructions(vae, x_input_train[0:10])

print("Rendering latent-space...")
ngdlutils.render_image_latent_space(vae.decoder, 10)

print("Rendering encodings...")
ngdlutils.render_encodings(vae.encoder, x_input_test, y_output_test)
# Out:
# Rendering history...
# Rendering reconstructions...
# Rendering latent-space...
# Rendering encodings...
