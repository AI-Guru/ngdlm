# %%
from keras import models, layers
from ngdlm import models as ngdlmodels
from ngdlm import utils as ngdlutils
from keras.datasets import mnist
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Train- and test-data.

# %%
(x_input_train, _), (x_input_test, y_output_test) = mnist.load_data()
x_input_train = x_input_train.astype("float32") / 255.0
x_input_test = x_input_test.astype("float32") / 255.0
print(x_input_train.shape)
print(x_input_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# # Plain autoencoder.

# %%
ae = ngdlutils.build_dense_ae(input_shape=(28, 28), latent_dim=32)
ae.compile(optimizer='adadelta', loss='binary_crossentropy')
ae.summary()

# Train.
print("Train...")
history = ae.fit(
        x_input_train, x_input_train,
        epochs=50,
        batch_size=128,
        shuffle=True,
        validation_data=(x_input_test, x_input_test)
    )
    
# Evaluate.
print("Evaluate...")
loss = ae.model.evaluate(x_input_test, x_input_test)
print("Loss:", loss)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# model_1 (Model)              (None, 32)                25120
# _________________________________________________________________
# model_2 (Model)              (None, 28, 28)            25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.3105 - val_loss: 0.2513
# Epoch 2/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.2304 - val_loss: 0.2095
# Epoch 3/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1996 - val_loss: 0.1886
# Epoch 4/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1833 - val_loss: 0.1755
# Epoch 5/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1720 - val_loss: 0.1657
# Epoch 6/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1633 - val_loss: 0.1578
# Epoch 7/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1558 - val_loss: 0.1509
# Epoch 8/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1493 - val_loss: 0.1448
# Epoch 9/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1437 - val_loss: 0.1396
# Epoch 10/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1389 - val_loss: 0.1350
# Epoch 11/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1346 - val_loss: 0.1309
# Epoch 12/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1306 - val_loss: 0.1272
# Epoch 13/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1270 - val_loss: 0.1236
# Epoch 14/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1236 - val_loss: 0.1204
# Epoch 15/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1206 - val_loss: 0.1176
# Epoch 16/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1179 - val_loss: 0.1151
# Epoch 17/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1156 - val_loss: 0.1130
# Epoch 18/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1136 - val_loss: 0.1110
# Epoch 19/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1118 - val_loss: 0.1094
# Epoch 20/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1104 - val_loss: 0.1080
# Epoch 21/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1091 - val_loss: 0.1068
# Epoch 22/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1079 - val_loss: 0.1058
# Epoch 23/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1069 - val_loss: 0.1048
# Epoch 24/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1060 - val_loss: 0.1040
# Epoch 25/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1052 - val_loss: 0.1032
# Epoch 26/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1044 - val_loss: 0.1025
# Epoch 27/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1038 - val_loss: 0.1018
# Epoch 28/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1031 - val_loss: 0.1012
# Epoch 29/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1026 - val_loss: 0.1007
# Epoch 30/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1020 - val_loss: 0.1002
# Epoch 31/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1015 - val_loss: 0.0998
# Epoch 32/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1011 - val_loss: 0.0993
# Epoch 33/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1007 - val_loss: 0.0990
# Epoch 34/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1003 - val_loss: 0.0986
# Epoch 35/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1000 - val_loss: 0.0983
# Epoch 36/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0996 - val_loss: 0.0980
# Epoch 37/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0993 - val_loss: 0.0977
# Epoch 38/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0991 - val_loss: 0.0975
# Epoch 39/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0988 - val_loss: 0.0972
# Epoch 40/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0986 - val_loss: 0.0971
# Epoch 41/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0984 - val_loss: 0.0969
# Epoch 42/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0982 - val_loss: 0.0967
# Epoch 43/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0981 - val_loss: 0.0965
# Epoch 44/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.0979 - val_loss: 0.0964
# Epoch 45/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0978 - val_loss: 0.0963
# Epoch 46/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0976 - val_loss: 0.0962
# Epoch 47/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0975 - val_loss: 0.0960
# Epoch 48/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0974 - val_loss: 0.0960
# Epoch 49/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0973 - val_loss: 0.0959
# Epoch 50/50
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.0972 - val_loss: 0.0958
# Evaluate...
# 10000/10000 [==============================] - 0s 20us/step
# Loss: 0.09578071253299714

# %% [markdown]
# # Visualizing plain autoencoder.

# %%
print("Rendering history...")
ngdlutils.render_history(history)

print("Rendering reconstructions...")
ngdlutils.render_image_reconstructions(ae, x_input_train[0:10])

print("Rendering latent-space...")
ngdlutils.render_image_latent_space(ae.decoder, 10)

print("Rendering encodings...")
ngdlutils.render_encodings(ae.encoder, x_input_test, y_output_test)
# Out:
# Rendering history...
# Rendering reconstructions...
# Rendering latent-space...
# Rendering encodings...
