# %%
from keras import models, layers
from ngdlm import models as ngdlmodels
from ngdlm import utils as ngdlutils
from keras.datasets import mnist
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Train- and test-data.

# %%
(x_input_train, _), (x_input_test, y_output_test) = mnist.load_data()
x_input_train = x_input_train.astype("float32") / 255.0
x_input_test = x_input_test.astype("float32") / 255.0
print(x_input_train.shape)
print(x_input_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# # Generator.

# %%
def train_generator():
    while True:
        yield x_input_train, x_input_train
        
def validate_generator():
    while True:
        yield x_input_test, x_input_test

# %% [markdown]
# # Plain autoencoder.

# %%
latent_dim = 32

# Create the encoder.
encoder_input = layers.Input(shape=(28, 28))
encoder_output = encoder_input
encoder_output = layers.Reshape((28 * 28,))(encoder_input)
encoder_output = layers.Dense(latent_dim, activation="relu")(encoder_output)
encoder = models.Model(encoder_input, encoder_output)

# Create the decoder.
decoder_input = layers.Input(shape=(latent_dim,))
decoder_output = layers.Dense(28 * 28, activation="sigmoid")(decoder_input)
decoder_output = layers.Reshape((28, 28))(decoder_output)
decoder = models.Model(decoder_input, decoder_output)

# Create the autoencoder.
ae = ngdlmodels.AE(encoder, decoder)
ae.compile(optimizer='adadelta', loss='binary_crossentropy')
ae.summary()

# Train.
print("Train...")
history = ae.fit_generator(
        train_generator(),
        steps_per_epoch=1,
        epochs=50,
        validation_data=validate_generator(),
        validation_steps=1
    )
    
# Evaluate.
print("Evaluate...")
loss = ae.model.evaluate(x_input_test, x_input_test)
print("Loss:", loss)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# reshape_6 (Reshape)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               25872
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 28, 28)            0
# =================================================================
# Total params: 25,872
# Trainable params: 25,872
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# model_3 (Model)              (None, 32)                25120
# _________________________________________________________________
# model_4 (Model)              (None, 28, 28)            25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# Epoch 1/50
# 1/1 [==============================] - 4s 4s/step - loss: 0.6943 - val_loss: 0.6937
# Epoch 2/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6937 - val_loss: 0.6931
# Epoch 3/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6931 - val_loss: 0.6926
# Epoch 4/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6926 - val_loss: 0.6920
# Epoch 5/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6920 - val_loss: 0.6915
# Epoch 6/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6915 - val_loss: 0.6909
# Epoch 7/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6910 - val_loss: 0.6904
# Epoch 8/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6904 - val_loss: 0.6898
# Epoch 9/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6898 - val_loss: 0.6892
# Epoch 10/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6892 - val_loss: 0.6885
# Epoch 11/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6886 - val_loss: 0.6878
# Epoch 12/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6879 - val_loss: 0.6871
# Epoch 13/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6872 - val_loss: 0.6863
# Epoch 14/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6864 - val_loss: 0.6855
# Epoch 15/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6856 - val_loss: 0.6845
# Epoch 16/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6846 - val_loss: 0.6835
# Epoch 17/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6836 - val_loss: 0.6824
# Epoch 18/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6825 - val_loss: 0.6811
# Epoch 19/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6813 - val_loss: 0.6797
# Epoch 20/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6799 - val_loss: 0.6782
# Epoch 21/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6784 - val_loss: 0.6765
# Epoch 22/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6767 - val_loss: 0.6745
# Epoch 23/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.6748 - val_loss: 0.6724
# Epoch 24/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6727 - val_loss: 0.6701
# Epoch 25/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6704 - val_loss: 0.6674
# Epoch 26/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6678 - val_loss: 0.6645
# Epoch 27/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6649 - val_loss: 0.6613
# Epoch 28/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6617 - val_loss: 0.6577
# Epoch 29/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6582 - val_loss: 0.6537
# Epoch 30/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6543 - val_loss: 0.6493
# Epoch 31/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6499 - val_loss: 0.6445
# Epoch 32/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6452 - val_loss: 0.6392
# Epoch 33/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6400 - val_loss: 0.6334
# Epoch 34/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6343 - val_loss: 0.6271
# Epoch 35/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6280 - val_loss: 0.6202
# Epoch 36/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6213 - val_loss: 0.6129
# Epoch 37/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6140 - val_loss: 0.6049
# Epoch 38/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6062 - val_loss: 0.5964
# Epoch 39/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5978 - val_loss: 0.5874
# Epoch 40/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5888 - val_loss: 0.5778
# Epoch 41/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5794 - val_loss: 0.5677
# Epoch 42/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5694 - val_loss: 0.5572
# Epoch 43/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5590 - val_loss: 0.5463
# Epoch 44/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5482 - val_loss: 0.5351
# Epoch 45/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5371 - val_loss: 0.5236
# Epoch 46/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5257 - val_loss: 0.5119
# Epoch 47/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5141 - val_loss: 0.5001
# Epoch 48/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5024 - val_loss: 0.4883
# Epoch 49/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.4907 - val_loss: 0.4766
# Epoch 50/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.4790 - val_loss: 0.4650
# Evaluate...
# 10000/10000 [==============================] - 0s 22us/step
# Loss: 0.46501302914619447

# %% [markdown]
# # Visualizing plain autoencoder.

# %%
print("Rendering history...")
ngdlutils.render_history(history)

print("Rendering reconstructions...")
ngdlutils.render_image_reconstructions(ae, x_input_train[0:10])

print("Rendering latent-space...")
ngdlutils.render_image_latent_space(ae.decoder, 10)

print("Rendering encodings...")
ngdlutils.render_encodings(ae.encoder, x_input_test, y_output_test)
# Out:
# Rendering history...
# Rendering reconstructions...
# Rendering latent-space...
# Rendering encodings...
